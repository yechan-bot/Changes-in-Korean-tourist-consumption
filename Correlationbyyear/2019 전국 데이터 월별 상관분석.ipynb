# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mlp
import seaborn as sns
import plotly.plotly as py
import cufflinks as cf
import plotly.offline as pyo
import plotly.graph_objs as go
cf.go_offline(connected=True)
from matplotlib import font_manager, rc
import scipy.stats as stats
font_name = font_manager.FontProperties(fname='c:/Windows/Fonts/malgun.ttf').get_name()
rc('font', family=font_name)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data0 = pd.read_excel("./2018~2020 목적지 검색 횟수 비교/2019 월별 전국 목적지 검색 횟수.xlsx")
data0
# Out:
#      월        전국    서울특별시   부산광역시   대구광역시    인천광역시   광주광역시   대전광역시   울산광역시  \
# 0    1  11369573  2082662  592442  297996   749992  197217  240361  157828
# 1    2  11211203  1952272  607552  297939   740936  194535  227185  152078
# 2    3  13144346  2254360  644747  345002   863792  219537  268953  184021
# 3    4  13180204  2192269  617084  348173   866502  219393  267877  177300
# 4    5  15331841  2407836  715370  375918  1016676  248018  295076  209786
# 5    6  15694410  2439868  724287  381746  1036729  251777  301302  205860
# 6    7  15856655  2446525  736281  385245   987423  259700  302708  219144
# 7    8  19776676  2713482  907249  439716  1179081  281400  340020  268294
# 8    9  14479165  2402145  671669  393987   958990  237326  290191  194098
# 9   10  17577844  2687247  794892  444421  1106770  270072  345453  237318
# 10  11  15984840  2650288  777955  443998   981020  274794  335515  234069
# ...

# %%
data1 = pd.read_excel("전국 전체 월별 방문자수 2019.xlsx")
data1
# Out:
#     구분     현지인(a)     외지인(b)   외국인(c)  외부방문자(b+c)  전년외부방문자(b'+c')  \
# 0    1  681997610  216038820  4755719   220794539       209401899
# 1    2  592580236  220373580  4793419   225166999       208252992
# 2    3  701908000  271202676  5274725   276477401       248720478
# 3    4  640311882  207230460  6145658   213376119       211823035
# 4    5  677198134  239603808  5538558   245142367       239308793
# 5    6  649221612  229760916  5148186   234909102       219622375
# 6    7  655834067  262371242  5857943   268229185       244939880
# 7    8  653247220  293042802  6371252   299414055       251357076
# 8    9  644024672  269626354  6298050   275924403       269774787
# 9   10  671461402  252879781  7284223   260164004       239477486
# 10  11  698550632  252847500  6940696   259788197       218325691
# 11  12  718104180  233213418  7212219   240425636       226473337
#
#     외부방문자 전년대비증감률(%)         합계
# 0                  5  902792149
# 1                  8  817747235
# ...

# %%
data2 = pd.read_excel("./2019~2020 지출액 비교/2019 월별 전국 관광지 지출액.xlsx")
data2
# Out:
#      월          숙박업         여행업         대중교통         렌터카          항공사  \
# 0    1  49996449699  9451076265  66681168630  1205932848  49039885156
# 1    2  47195003175  5866705399  59058969697  1342363676  44440055863
# 2    3  45462779889  5335203008  63865838215  1411301490  46663133939
# 3    4  44332744646  6341655126  65669222294  1604218805  41318299980
# 4    5  48261718399  5811565864  67619030192  1876817811  43328178177
# 5    6  48506443868  5211042046  63031916138  1989396669  48211908115
# 6    7  51608157115  7987831384  68406601665  2363352106  52711586136
# 7    8  65343224129  5247788823  76619969776  3010939882  41257803996
# 8    9  44606513311  5501151049  60918243872  2124110625  36503902535
# 9   10  48025891645  4536673594  67105389266  2695294945  40420963715
# 10  11  45343133677  4044203816  63624428640  2527226145  39255954450
# 11  12  57371514005  5552594482  65557803406  2824743323  54981326317
#
# ...

# %%
search2019 = data0["전국"]
visitor2019 = data1["합계"]
price2019 = data2["합계"]

# %%
data= pd.DataFrame({"search" : search2019, "visitor" :  visitor2019, "price" : price2019})
data
# Out:
#       search    visitor          price
# 0   11369573  902792149  1626703667130
# 1   11211203  817747235  1538113279405
# 2   13144346  978385401  1764807242399
# 3   13180204  853688000  1719807697479
# 4   15331841  922340500  1908633089253
# 5   15694410  884130714  1805411651074
# 6   15856655  924063252  1785880960792
# 7   19776676  952661274  1861928525182
# 8   14479165  919949076  1643659078230
# 9   17577844  931625406  1801226635607
# 10  15984840  958338828  1738106745729
# 11  16515922  958529817  1838596300782

# %%
corr = data.corr(method='pearson')
corr
# Out:
#            search   visitor     price
# search   1.000000  0.565252  0.765905
# visitor  0.565252  1.000000  0.594064
# price    0.765905  0.594064  1.000000

# %%
dataheatmap = sns.heatmap(corr, cbar = True, annot = True, annot_kws={'size' : 20}, fmt = '.2f', square = True)

# %%
sns.pairplot(data, kind='reg', height=4)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.subplot(1, 3, 1)
plt.scatter(search2019, visitor2019)
plt.xlabel("2019 목적지 검색 횟수")
plt.ylabel("2019 방문자 수")
plt.grid()

plt.subplot(1, 3, 2)
plt.scatter(search2019, price2019)
plt.xlabel("2019 목적지 검색 횟수")
plt.ylabel("2019 지출액")
plt.grid()

plt.subplot(1, 3, 3)
plt.scatter(visitor2019, price2019)
plt.xlabel("2019 방문자 수")
plt.ylabel("2019 지출액")
plt.grid()

plt.tight_layout()
#plt.title("2019 목적지 검색, 방문자 수, 지출액 상관 분석")

plt.show()

# %%
plt.scatter(search2019, visitor2019)
plt.xlabel("2019 목적지 검색 횟수")
plt.ylabel("2019 방문자 수")
plt.grid()

plt.show()

# %%
plt.scatter(search2019, price2019)
plt.xlabel("2019 목적지 검색 횟수")
plt.ylabel("2019 지출액")
plt.grid()


plt.show()

# %%
plt.scatter(visitor2019, price2019)
plt.xlabel("2019 방문자 수")
plt.ylabel("2019 지출액")
plt.grid()

plt.tight_layout()
#plt.title("2019 목적지 검색, 방문자 수, 지출액 상관 분석")

plt.show()

# %%
sns.pairplot(data0, kind='reg', height=4)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data=data0_1, annot=True, fmt='.0f')
# Out:
# <AxesSubplot:>

# %%
corr = stats.pearsonr(data0_1, data1_1)
corr
# Out:
# (0.18730716782420065, 0.5599418789517685)

# %%
data1 = pd.read_excel("2019 월별 전국 목적지 검색 횟수.xlsx")
data1
data2 = pd.read_excel("2020 월별 전국 목적지 검색 횟수.xlsx")
data2
# Out:
#      월        전국    서울특별시    부산광역시   대구광역시    인천광역시   광주광역시   대전광역시   울산광역시  \
# 0    1  14853073  2550590   786249  416745   962036  260288  313511  217346
# 1    2  11435517  2053750   591773  278078   730246  187689  248002  168911
# 2    3  11883273  1971848   545705  205252   808694  191010  222164  152234
# 3    4  14147725  2136654   660202  284616   895785  227216  271888  191871
# 4    5  18297169  2564736   886446  404393  1085850  295918  353352  260810
# 5    6  17163348  2450030   831212  416554   970220  284147  318957  252089
# 6    7  18986722  2686981   916603  461666  1095181  211633  318551  273773
# 7    8  20674548  2591326  1045367  496967  1103157  261580  367077  316662
# 8    9  15857505  2252264   713581  417611  1012143  214262  316050  199020
# 9   10  20782034  2719121   912478  522805  1238703  298315  391584  279358
# 10  11  17983397  2643978   871824  494568  1000339  273222  382672  262965
# ...

# %%
sejong = pd.read_excel('2020 3월 세종 목적지 검색 횟수.xlsx')
sejong
# Out:
#      월    전체  자연관광지  역사관광지  휴양관광지  공연/행사  문화시설  레포츠(육상/해상/항공)   쇼핑   식음료  숙박  \
# 0    1  2216    431     25     15     88     4             63  179  1282  11
# 1    2  1419    214     10     26     50    27             45  124   778  36
# 2    3  1600    215     11     27     42    17             56  120   949  58
# 3    4  1599    183     10     32     36    14             63  123  1001  43
# 4    5  1770    197     13     21     41    21             61  144  1113  51
# 5    6  1941    270      5     24     63    15             80  127  1169  51
# 6    7  2654    429     22     43    127    13             90  179  1603  40
# 7    8  3485   1029     46     59     74    18            118  167  1796  22
# 8    9  1180    158     13     23     31    21             48   98   673  24
# 9   10  1198     77      3     15     32    24             47  102   776  39
# 10  11  1691    214     12     29     46    29             84  118   992  50
# ...

# %%
df = round(sejong.groupby('월')[['역사관광지','휴양관광지','공연/행사','문화시설']].mean())
df
# Out:
#     역사관광지  휴양관광지  공연/행사  문화시설
# 월
# 1      25     15     88     4
# 2      10     26     50    27
# 3      11     27     42    17
# 4      10     32     36    14
# 5      13     21     41    21
# 6       5     24     63    15
# 7      22     43    127    13
# 8      46     59     74    18
# 9      13     23     31    21
# 10      3     15     32    24
# 11     12     29     46    29
# 12     10     36     52    18
# 13      9     24     43    18
# 14     37     62     67     0
# 15     41     62     57     0
# 16     14     22     29     9
# 17      9     16     25    18
# 18     21     47     38    10
# 19      6     16     31    14
# 20     24     40     39    16
# 21     59    116     73     7
# 22     66    125     44     9
# 23      8     36     32     8
# 24      8     30     24    26
# 25     13     52     33    53
# 26      5     17     46    19
# 27     15     19     45    13
# 28     31     68     56     4
# 29     52    103     41     8
# 30      3     42     19    18
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data=df, annot=True, fmt='.0f',linewidths=1, cmap='YlGnBu')
# Out:
# <AxesSubplot:ylabel='월'>

# %%
pip install pyecharts
# Out:
# ...
#
# ...
#   Created wheel for simplejson: filename=simplejson-3.17.2-py3-none-any.whl size=55464 sha256=642515ddd53612c8b4bae3930780e211c85fe960dd122ecc6e437d3ddcc3a66d
#   Stored in directory: c:\users\yechan\appdata\local\pip\cache\wheels\17\72\7d\df0984c925921e22322ea462a6f861e9d0617881192deb9b8d
# Successfully built simplejson
# ...

# %%
import pyecharts

# %%
from pyecharts import Pie

attr = ['A','B','C','D','E','F']
v1 = [10, 20, 30, 40, 50, 60]
v2 = [38, 28, 58, 48, 78, 68]
pie = Pie("pie chart", title_pos="center", width=600)
pie.add("A", attr, v1, center=[25, 50], is_random=True, radius=[30, 75], rosetype='radius')
pie.add("B", attr, v2, center=[75, 50], is_randome=True, radius=[30, 75], rosetype='area', is_legend_show=False,
       is_label_show=True)
pie
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-7e6b98db1bab> in <module>
# ----> 1 from pyecharts import Pie
#       2
#       3 attr = ['A','B','C','D','E','F']
#       4 v1 = [10, 20, 30, 40, 50, 60]
#       5 v2 = [38, 28, 58, 48, 78, 68]
#
# ImportError: cannot import name 'Pie' from 'pyecharts' (C:\Users\yechan\anaconda3\lib\site-packages\pyecharts\__init__.py)
